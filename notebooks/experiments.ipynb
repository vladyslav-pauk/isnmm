# %% [markdown]
# ## Nonlinearity removal

# %% [markdown]
# ## Latent correlations

# %% [markdown]
# ## Sweep results

# %% [markdown]
# Set `save=True` to save the figures to the `save_dir` directory.

# %%
from src.scripts.analyze_sweep import analyze_sweep
from src.utils.wandb_tools import login_wandb
    
experiment = "synthetic_data"
sweep_id = "2ag3ze65"

login_wandb(experiment)
analyze_sweep(experiment, sweep_id, save=False, save_dir='notebooks/figures')
# Out:
# +--------------+-------+------------------+------------------+
# | model_name   |   snr |   latent_mse_avg |   latent_mse_std |
# +==============+=======+==================+==================+
# | nisca        |    30 |         0.129135 |                0 |
# +--------------+-------+------------------+------------------+
