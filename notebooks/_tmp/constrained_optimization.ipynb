# %%
import numpy as np
from scipy.linalg import svd

# Function to compute the null space of a matrix
def null_space(A, rtol=1e-5):
    # Perform Singular Value Decomposition (SVD)
    u, s, vh = svd(A)
    
    # Find the rank of A based on the tolerance
    rank = (s > rtol * s[0]).sum()
    
    # The null space is the set of vectors in vh that correspond to zero singular values
    null_space_basis = vh[rank:].conj().T
    
    return null_space_basis

# Example matrix A (N x M)
A = np.array([[1, 0],
              [0, 1],
              [1, 1]])

# Transpose of A
A_transpose = A.T

# Find the null space of A transpose (this gives us C)
C = null_space(A_transpose)

# Show results
print("Matrix A:\n", A)
print("Transpose of A:\n", A_transpose)
print("Constraint matrix C (null space of A^T):\n", C)
# Out:
# Matrix A:
#  [[1 0]
#  [0 1]
#  [1 1]]
# Transpose of A:
#  [[1 0 1]
#  [0 1 1]]
# Constraint matrix C (null space of A^T):
#  [[-0.57735027]
#  [-0.57735027]
#  [ 0.57735027]]

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np

# Autoencoder Definition
class Autoencoder(nn.Module):
    def __init__(self, input_dim, latent_dim):
        super(Autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, latent_dim)
        )
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, input_dim)
        )

    def forward(self, x):
        z = self.encoder(x)
        recon_x = self.decoder(z)
        return recon_x, z

# Constraint Function: Forces latent space to satisfy z1^2 - z2^2 = 1
def constraint_loss(z):
    g1 = z[:, 0]**2 - z[:, 1]**2 - 1  # Hyperbola constraint: z1^2 - z2^2 = 1
    return torch.mean(g1**2)

# Training loop
def train_autoencoder(autoencoder, dataloader, epochs=100, lambda_coeff=1e-3, lr=1e-2):
    optimizer = optim.Adam(autoencoder.parameters(), lr=lr)
    loss_history = []
    constraint_history = []

    for epoch in range(epochs):
        epoch_loss = 0.0
        epoch_constraint_loss = 0.0
        for data in dataloader:
            x = data  # input data
            
            # Forward pass
            recon_x, z = autoencoder(x)
            
            # Compute losses
            reconstruction_loss = nn.MSELoss()(recon_x, x)
            manifold_constraint_loss = constraint_loss(z)
            total_loss = reconstruction_loss + lambda_coeff * manifold_constraint_loss
            
            # Backward pass and optimization
            optimizer.zero_grad()
            total_loss.backward()
            optimizer.step()
            
            # Log losses
            epoch_loss += reconstruction_loss.item()
            epoch_constraint_loss += manifold_constraint_loss.item()
        
        # Record average losses for this epoch
        loss_history.append(epoch_loss / len(dataloader))
        constraint_history.append(epoch_constraint_loss / len(dataloader))

        if epoch % 10 == 0:
            print(f'Epoch [{epoch}/{epochs}], Loss: {epoch_loss:.4f}, Constraint Loss: {epoch_constraint_loss:.4f}')
    
    return loss_history, constraint_history

# Visualization function for training results
def visualize_training(loss_history, constraint_history):
    epochs = len(loss_history)
    
    # Plot Reconstruction Loss and Constraint Loss
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(range(epochs), loss_history, label="Reconstruction Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Reconstruction Loss During Training")
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(range(epochs), constraint_history, label="Constraint Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Constraint Loss")
    plt.title("Constraint Loss During Training")
    plt.legend()

    plt.tight_layout()
    plt.show()

# Visualization function for the latent space
def visualize_latent_space(z):
    # Create a meshgrid for z1 and z2
    z1_range = np.linspace(np.min(z[:, 0]) - 1, np.max(z[:, 0]) + 1, 100)
    z2_range = np.linspace(np.min(z[:, 1]) - 1, np.max(z[:, 1]) + 1, 100)
    Z1, Z2 = np.meshgrid(z1_range, z2_range)

    # Compute the function F = z1^2 - z2^2 - 1 over the grid
    F = Z1**2 - Z2**2 - 1

    # Plot latent points
    plt.figure(figsize=(6, 6))
    plt.scatter(z[:, 0], z[:, 1], c='b', label="Latent Points")

    # Plot the contour where F = 0 (which corresponds to z1^2 - z2^2 = 1)
    manifold = plt.contour(Z1, Z2, F, levels=[0], colors='r')
    plt.clabel(manifold, inline=1, fontsize=10)

    # Add labels and legend
    plt.xlabel('z1')
    plt.ylabel('z2')
    plt.title('Latent Space and Manifold: z1^2 - z2^2 = 1')
    plt.legend()
    plt.axis('equal')
    plt.show()

# Synthetic Data Generation
def generate_synthetic_data(num_samples=1000, input_dim=3):
    # Random data for input, can be replaced with any dataset
    data = np.random.randn(num_samples, input_dim).astype(np.float32)
    return torch.tensor(data)

# Main
if __name__ == "__main__":
    # Define parameters
    input_dim = 3   # Dimensionality of input data
    latent_dim = 2  # Dimensionality of latent space
    num_samples = 10000
    batch_size = 1000
    epochs = 10000

    # Create synthetic data
    dataset = generate_synthetic_data(num_samples, input_dim)
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)

    # Initialize and train the autoencoder
    autoencoder = Autoencoder(input_dim=input_dim, latent_dim=latent_dim)
    loss_history, constraint_history = train_autoencoder(autoencoder, dataloader, epochs=epochs, lambda_coeff=1e-2)

    # Visualize training results
    visualize_training(loss_history, constraint_history)

    # Generate some latent space visualization
    sample_data = next(iter(dataloader))
    _, z = autoencoder(sample_data)
    z = z.detach().numpy()  # Detach tensor from computation graph before converting to NumPy

    # Visualize the latent space with the manifold constraint
    visualize_latent_space(z)
# Out:
# Epoch [0/10000], Loss: 8.3530, Constraint Loss: 18.9341
# Epoch [10/10000], Loss: 1.6413, Constraint Loss: 7.3739
# Epoch [20/10000], Loss: 1.4831, Constraint Loss: 6.5463
# Epoch [30/10000], Loss: 1.1105, Constraint Loss: 6.7458
# Epoch [40/10000], Loss: 1.0081, Constraint Loss: 6.4404
# Epoch [50/10000], Loss: 0.9940, Constraint Loss: 6.3800
# Epoch [60/10000], Loss: 0.9807, Constraint Loss: 6.6365
# Epoch [70/10000], Loss: 0.9823, Constraint Loss: 7.0705
# Epoch [80/10000], Loss: 0.9670, Constraint Loss: 6.8380
# Epoch [90/10000], Loss: 0.8511, Constraint Loss: 7.5213
# Epoch [100/10000], Loss: 1.1760, Constraint Loss: 7.9017
# Epoch [110/10000], Loss: 0.8022, Constraint Loss: 6.2573
# Epoch [120/10000], Loss: 0.9418, Constraint Loss: 5.2061
# Epoch [130/10000], Loss: 0.7792, Constraint Loss: 5.5952
# Epoch [140/10000], Loss: 0.8275, Constraint Loss: 7.9495
# Epoch [150/10000], Loss: 1.0168, Constraint Loss: 7.5955
# Epoch [160/10000], Loss: 0.7876, Constraint Loss: 5.5219
# Epoch [170/10000], Loss: 0.6617, Constraint Loss: 5.8606
# Epoch [180/10000], Loss: 0.6986, Constraint Loss: 5.9813
# Epoch [190/10000], Loss: 0.7728, Constraint Loss: 6.3363
# Epoch [200/10000], Loss: 0.9145, Constraint Loss: 6.6378
# Epoch [210/10000], Loss: 1.3731, Constraint Loss: 5.0090
# Epoch [220/10000], Loss: 0.6542, Constraint Loss: 5.5665
# Epoch [230/10000], Loss: 0.7766, Constraint Loss: 6.0831
# Epoch [240/10000], Loss: 0.8229, Constraint Loss: 4.9480
# Epoch [250/10000], Loss: 0.6102, Constraint Loss: 4.9620
# Epoch [260/10000], Loss: 0.5868, Constraint Loss: 4.7304
# Epoch [270/10000], Loss: 0.5594, Constraint Loss: 4.9520
# Epoch [280/10000], Loss: 0.6281, Constraint Loss: 4.9074
# Epoch [290/10000], Loss: 0.6869, Constraint Loss: 4.6860
# Epoch [300/10000], Loss: 0.7146, Constraint Loss: 4.7263
# Epoch [310/10000], Loss: 0.6669, Constraint Loss: 4.3417
# Epoch [320/10000], Loss: 0.6472, Constraint Loss: 4.5384
# Epoch [330/10000], Loss: 0.5592, Constraint Loss: 5.0657
# Epoch [340/10000], Loss: 0.6020, Constraint Loss: 4.7242
# Epoch [350/10000], Loss: 0.5881, Constraint Loss: 4.3602
# Epoch [360/10000], Loss: 0.6763, Constraint Loss: 4.4279
# Epoch [370/10000], Loss: 0.6479, Constraint Loss: 4.1216
# Epoch [380/10000], Loss: 0.6916, Constraint Loss: 4.5719
# Epoch [390/10000], Loss: 0.7122, Constraint Loss: 4.2547
# Epoch [400/10000], Loss: 0.7974, Constraint Loss: 4.0312
# Epoch [410/10000], Loss: 0.9159, Constraint Loss: 4.1289
# Epoch [420/10000], Loss: 0.6782, Constraint Loss: 4.1239
# Epoch [430/10000], Loss: 0.6578, Constraint Loss: 3.7104
# Epoch [440/10000], Loss: 0.6276, Constraint Loss: 3.3506
# Epoch [450/10000], Loss: 0.7233, Constraint Loss: 3.2859
# Epoch [460/10000], Loss: 0.6683, Constraint Loss: 3.0883
# Epoch [470/10000], Loss: 0.7078, Constraint Loss: 3.1531
# Epoch [480/10000], Loss: 0.7229, Constraint Loss: 3.5870
# Epoch [490/10000], Loss: 0.5160, Constraint Loss: 3.4014
# Epoch [500/10000], Loss: 0.5898, Constraint Loss: 3.0873
# Epoch [510/10000], Loss: 0.6682, Constraint Loss: 2.9591
# Epoch [520/10000], Loss: 0.5995, Constraint Loss: 3.3713
# Epoch [530/10000], Loss: 0.6906, Constraint Loss: 3.4296
# Epoch [540/10000], Loss: 0.6650, Constraint Loss: 3.0632
# Epoch [550/10000], Loss: 0.6248, Constraint Loss: 4.1433
# Epoch [560/10000], Loss: 0.6682, Constraint Loss: 4.6046
# Epoch [570/10000], Loss: 0.8895, Constraint Loss: 3.8848
# Epoch [580/10000], Loss: 0.9183, Constraint Loss: 4.5595
# Epoch [590/10000], Loss: 0.8495, Constraint Loss: 4.2377
# Epoch [600/10000], Loss: 0.7708, Constraint Loss: 3.0731
# Epoch [610/10000], Loss: 0.9574, Constraint Loss: 2.4309
# Epoch [620/10000], Loss: 0.8968, Constraint Loss: 2.8963
# Epoch [630/10000], Loss: 0.8048, Constraint Loss: 3.7151
# Epoch [640/10000], Loss: 0.6490, Constraint Loss: 3.2186
# Epoch [650/10000], Loss: 0.6252, Constraint Loss: 2.6853
# Epoch [660/10000], Loss: 0.6634, Constraint Loss: 2.4716
# Epoch [670/10000], Loss: 0.5781, Constraint Loss: 2.5353
# Epoch [680/10000], Loss: 0.7304, Constraint Loss: 2.7400
# Epoch [690/10000], Loss: 0.6827, Constraint Loss: 2.2708
# Epoch [700/10000], Loss: 0.7244, Constraint Loss: 2.1235
# Epoch [710/10000], Loss: 0.6667, Constraint Loss: 2.5176
# Epoch [720/10000], Loss: 0.7041, Constraint Loss: 2.4744
# Epoch [730/10000], Loss: 0.6695, Constraint Loss: 2.5731
# Epoch [740/10000], Loss: 0.7370, Constraint Loss: 2.7601
# Epoch [750/10000], Loss: 0.6889, Constraint Loss: 2.8851
# Epoch [760/10000], Loss: 0.6442, Constraint Loss: 3.3324
# Epoch [770/10000], Loss: 0.8328, Constraint Loss: 4.6943
# Epoch [780/10000], Loss: 0.8084, Constraint Loss: 4.0710
# Epoch [790/10000], Loss: 0.6986, Constraint Loss: 3.8444
# Epoch [800/10000], Loss: 0.6152, Constraint Loss: 3.5745
# Epoch [810/10000], Loss: 0.6220, Constraint Loss: 3.6243
# Epoch [820/10000], Loss: 0.6186, Constraint Loss: 3.3421
# Epoch [830/10000], Loss: 0.7966, Constraint Loss: 3.4900
# Epoch [840/10000], Loss: 1.2407, Constraint Loss: 6.4090
# Epoch [850/10000], Loss: 0.9878, Constraint Loss: 4.8850
# Epoch [860/10000], Loss: 0.8448, Constraint Loss: 3.6461
# Epoch [870/10000], Loss: 0.6247, Constraint Loss: 3.5128
# Epoch [880/10000], Loss: 0.7048, Constraint Loss: 3.0379
# Epoch [890/10000], Loss: 0.7590, Constraint Loss: 2.9870
# Epoch [900/10000], Loss: 0.6697, Constraint Loss: 3.1227
# Epoch [910/10000], Loss: 0.6712, Constraint Loss: 3.0601
# Epoch [920/10000], Loss: 0.6691, Constraint Loss: 3.1723
# Epoch [930/10000], Loss: 0.6429, Constraint Loss: 3.2607
# Epoch [940/10000], Loss: 0.7073, Constraint Loss: 3.1552
# Epoch [950/10000], Loss: 0.7387, Constraint Loss: 3.3732
# Epoch [960/10000], Loss: 0.6320, Constraint Loss: 2.9092
# Epoch [970/10000], Loss: 0.5925, Constraint Loss: 3.0602
# Epoch [980/10000], Loss: 0.6589, Constraint Loss: 2.9000
# Epoch [990/10000], Loss: 0.6656, Constraint Loss: 2.8694
# Epoch [1000/10000], Loss: 0.6022, Constraint Loss: 3.0945
# Epoch [1010/10000], Loss: 0.6264, Constraint Loss: 2.9113
# Epoch [1020/10000], Loss: 0.5377, Constraint Loss: 2.8366
# Epoch [1030/10000], Loss: 0.9199, Constraint Loss: 3.9513
# Epoch [1040/10000], Loss: 0.8185, Constraint Loss: 3.1475
# Epoch [1050/10000], Loss: 0.9122, Constraint Loss: 3.5807
# Epoch [1060/10000], Loss: 0.6954, Constraint Loss: 3.8084
# Epoch [1070/10000], Loss: 0.8024, Constraint Loss: 2.8721
# Epoch [1080/10000], Loss: 0.6755, Constraint Loss: 3.3669
# Epoch [1090/10000], Loss: 0.6289, Constraint Loss: 3.1361
# Epoch [1100/10000], Loss: 0.7319, Constraint Loss: 3.5449
# Epoch [1110/10000], Loss: 0.6353, Constraint Loss: 4.1223
# Epoch [1120/10000], Loss: 0.5845, Constraint Loss: 3.9198
# Epoch [1130/10000], Loss: 0.6206, Constraint Loss: 3.6965
# Epoch [1140/10000], Loss: 0.6067, Constraint Loss: 3.3644
# Epoch [1150/10000], Loss: 0.6247, Constraint Loss: 3.1386
# Epoch [1160/10000], Loss: 0.6311, Constraint Loss: 3.2842
# Epoch [1170/10000], Loss: 0.6258, Constraint Loss: 2.9812
# Epoch [1180/10000], Loss: 0.7852, Constraint Loss: 3.2250
# Epoch [1190/10000], Loss: 0.6936, Constraint Loss: 3.0521
# Epoch [1200/10000], Loss: 0.6176, Constraint Loss: 3.0148
# Epoch [1210/10000], Loss: 0.5615, Constraint Loss: 3.4204
# Epoch [1220/10000], Loss: 0.5459, Constraint Loss: 3.2677
# Epoch [1230/10000], Loss: 0.7837, Constraint Loss: 3.9384
# Epoch [1240/10000], Loss: 0.5493, Constraint Loss: 4.1771
# Epoch [1250/10000], Loss: 0.5737, Constraint Loss: 3.6127
# Epoch [1260/10000], Loss: 0.5750, Constraint Loss: 3.3548
# Epoch [1270/10000], Loss: 0.6209, Constraint Loss: 2.7683
# Epoch [1280/10000], Loss: 0.5352, Constraint Loss: 3.6310
# Epoch [1290/10000], Loss: 0.6290, Constraint Loss: 3.1033
# Epoch [1300/10000], Loss: 0.6348, Constraint Loss: 2.7931
# Epoch [1310/10000], Loss: 0.8322, Constraint Loss: 2.4310
# Epoch [1320/10000], Loss: 0.7446, Constraint Loss: 3.8080
# Epoch [1330/10000], Loss: 0.7111, Constraint Loss: 3.0478
# Epoch [1340/10000], Loss: 0.6635, Constraint Loss: 3.5270
# Epoch [1350/10000], Loss: 0.7879, Constraint Loss: 4.2081
# Epoch [1360/10000], Loss: 0.6644, Constraint Loss: 3.6429
# Epoch [1370/10000], Loss: 0.7607, Constraint Loss: 4.3775
# Epoch [1380/10000], Loss: 0.6890, Constraint Loss: 5.1507
# Epoch [1390/10000], Loss: 0.6679, Constraint Loss: 5.1611
# Epoch [1400/10000], Loss: 0.8581, Constraint Loss: 3.0463
# Epoch [1410/10000], Loss: 0.9427, Constraint Loss: 4.2617
# Epoch [1420/10000], Loss: 0.9281, Constraint Loss: 4.8136
# Epoch [1430/10000], Loss: 0.9415, Constraint Loss: 3.9775
# Epoch [1440/10000], Loss: 0.7588, Constraint Loss: 3.5952
# Epoch [1450/10000], Loss: 0.9521, Constraint Loss: 5.5589
# Epoch [1460/10000], Loss: 0.7266, Constraint Loss: 4.0323
# Epoch [1470/10000], Loss: 0.7704, Constraint Loss: 4.5929
# Epoch [1480/10000], Loss: 0.8341, Constraint Loss: 3.8738
# Epoch [1490/10000], Loss: 0.9212, Constraint Loss: 5.5250
# Epoch [1500/10000], Loss: 0.7197, Constraint Loss: 3.9533
# Epoch [1510/10000], Loss: 0.6246, Constraint Loss: 4.1589
# Epoch [1520/10000], Loss: 0.6872, Constraint Loss: 4.5284
# Epoch [1530/10000], Loss: 0.6589, Constraint Loss: 5.2798
# Epoch [1540/10000], Loss: 0.6368, Constraint Loss: 4.9312
# Epoch [1550/10000], Loss: 0.6181, Constraint Loss: 4.3961
# Epoch [1560/10000], Loss: 0.5410, Constraint Loss: 4.4016
# Epoch [1570/10000], Loss: 0.8772, Constraint Loss: 5.3949
# Epoch [1580/10000], Loss: 0.6504, Constraint Loss: 4.7698
# Epoch [1590/10000], Loss: 0.5949, Constraint Loss: 4.0651
# Epoch [1600/10000], Loss: 0.5718, Constraint Loss: 4.3754
# Epoch [1610/10000], Loss: 0.5841, Constraint Loss: 4.4181
# Epoch [1620/10000], Loss: 0.5763, Constraint Loss: 3.8919
# Epoch [1630/10000], Loss: 0.6608, Constraint Loss: 3.5273
# Epoch [1640/10000], Loss: 0.5040, Constraint Loss: 3.6543
# Epoch [1650/10000], Loss: 0.6164, Constraint Loss: 4.0648
# Epoch [1660/10000], Loss: 0.7001, Constraint Loss: 3.5287
# Epoch [1670/10000], Loss: 0.6979, Constraint Loss: 4.6316
# Epoch [1680/10000], Loss: 0.7270, Constraint Loss: 4.3388
# Epoch [1690/10000], Loss: 0.6701, Constraint Loss: 3.8881
# Epoch [1700/10000], Loss: 0.7729, Constraint Loss: 3.8884
# Epoch [1710/10000], Loss: 0.8346, Constraint Loss: 4.2416
# Epoch [1720/10000], Loss: 0.7575, Constraint Loss: 4.0559
# Epoch [1730/10000], Loss: 0.6770, Constraint Loss: 4.6531
# Epoch [1740/10000], Loss: 0.7744, Constraint Loss: 3.6839
# Epoch [1750/10000], Loss: 0.7514, Constraint Loss: 3.6370
# Epoch [1760/10000], Loss: 0.7841, Constraint Loss: 3.5472
# Epoch [1770/10000], Loss: 0.8491, Constraint Loss: 5.8717
# Epoch [1780/10000], Loss: 0.8539, Constraint Loss: 3.8168
# Epoch [1790/10000], Loss: 0.9639, Constraint Loss: 3.6473
# Epoch [1800/10000], Loss: 0.8985, Constraint Loss: 3.0947
# Epoch [1810/10000], Loss: 0.9113, Constraint Loss: 2.9964
# Epoch [1820/10000], Loss: 0.8548, Constraint Loss: 4.3725
# Epoch [1830/10000], Loss: 0.7666, Constraint Loss: 5.4775
# Epoch [1840/10000], Loss: 0.6952, Constraint Loss: 3.1857
# Epoch [1850/10000], Loss: 0.7139, Constraint Loss: 3.8237
# Epoch [1860/10000], Loss: 0.6654, Constraint Loss: 3.5395
# Epoch [1870/10000], Loss: 0.6624, Constraint Loss: 5.2952
# Epoch [1880/10000], Loss: 0.8860, Constraint Loss: 6.4352
# Epoch [1890/10000], Loss: 1.0992, Constraint Loss: 6.4698
# Epoch [1900/10000], Loss: 0.8330, Constraint Loss: 5.6412
# Epoch [1910/10000], Loss: 0.6364, Constraint Loss: 5.9704
# Epoch [1920/10000], Loss: 0.7381, Constraint Loss: 4.8537
# Epoch [1930/10000], Loss: 0.6583, Constraint Loss: 3.9873
# Epoch [1940/10000], Loss: 0.6101, Constraint Loss: 4.1885
# Epoch [1950/10000], Loss: 0.6331, Constraint Loss: 4.3527
# Epoch [1960/10000], Loss: 0.6298, Constraint Loss: 4.1212
# Epoch [1970/10000], Loss: 0.5243, Constraint Loss: 3.6912
# Epoch [1980/10000], Loss: 0.6357, Constraint Loss: 4.0586
# Epoch [1990/10000], Loss: 0.6307, Constraint Loss: 3.7952
# Epoch [2000/10000], Loss: 0.5796, Constraint Loss: 3.9371
# Epoch [2010/10000], Loss: 0.7555, Constraint Loss: 4.1547
# Epoch [2020/10000], Loss: 0.5545, Constraint Loss: 3.8920
# Epoch [2030/10000], Loss: 0.6828, Constraint Loss: 4.3203
# Epoch [2040/10000], Loss: 0.6633, Constraint Loss: 4.3095
# Epoch [2050/10000], Loss: 0.6584, Constraint Loss: 3.8829
# Epoch [2060/10000], Loss: 0.6854, Constraint Loss: 3.7570
# Epoch [2070/10000], Loss: 0.7026, Constraint Loss: 3.5228
# Epoch [2080/10000], Loss: 0.7583, Constraint Loss: 4.3009
# Epoch [2090/10000], Loss: 0.7790, Constraint Loss: 3.5914
# Epoch [2100/10000], Loss: 0.7347, Constraint Loss: 4.3393
# Epoch [2110/10000], Loss: 0.8914, Constraint Loss: 4.0206
# Epoch [2120/10000], Loss: 0.6792, Constraint Loss: 3.9845
# Epoch [2130/10000], Loss: 0.5567, Constraint Loss: 3.4557
# Epoch [2140/10000], Loss: 1.0032, Constraint Loss: 3.9146
# Epoch [2150/10000], Loss: 0.6219, Constraint Loss: 3.7358
# Epoch [2160/10000], Loss: 0.6455, Constraint Loss: 3.9711
# Epoch [2170/10000], Loss: 0.5158, Constraint Loss: 3.4105
# Epoch [2180/10000], Loss: 0.6451, Constraint Loss: 2.5212
# Epoch [2190/10000], Loss: 0.6144, Constraint Loss: 2.9649
# Epoch [2200/10000], Loss: 0.5703, Constraint Loss: 4.4564
# Epoch [2210/10000], Loss: 0.5976, Constraint Loss: 4.2432
# Epoch [2220/10000], Loss: 0.6038, Constraint Loss: 4.1583
# Epoch [2230/10000], Loss: 0.5657, Constraint Loss: 4.0222
# Epoch [2240/10000], Loss: 0.9440, Constraint Loss: 3.9173
# Epoch [2250/10000], Loss: 0.5537, Constraint Loss: 3.5427
# Epoch [2260/10000], Loss: 0.7218, Constraint Loss: 3.3501
# Epoch [2270/10000], Loss: 0.5703, Constraint Loss: 3.4186
# Epoch [2280/10000], Loss: 0.6106, Constraint Loss: 3.5665
# Epoch [2290/10000], Loss: 0.7428, Constraint Loss: 3.6405
# Epoch [2300/10000], Loss: 0.6218, Constraint Loss: 3.6980
# Epoch [2310/10000], Loss: 0.6831, Constraint Loss: 3.8669
# Epoch [2320/10000], Loss: 0.6786, Constraint Loss: 3.0904
# Epoch [2330/10000], Loss: 0.7920, Constraint Loss: 2.8701
# Epoch [2340/10000], Loss: 0.8262, Constraint Loss: 3.0259
# Epoch [2350/10000], Loss: 0.9335, Constraint Loss: 3.4872
# Epoch [2360/10000], Loss: 0.8097, Constraint Loss: 3.4854
# Epoch [2370/10000], Loss: 0.7413, Constraint Loss: 3.0461
# Epoch [2380/10000], Loss: 0.6815, Constraint Loss: 3.0078
# Epoch [2390/10000], Loss: 0.8136, Constraint Loss: 2.9133
# Epoch [2400/10000], Loss: 0.8367, Constraint Loss: 3.1804
# Epoch [2410/10000], Loss: 0.7716, Constraint Loss: 2.6735
# Epoch [2420/10000], Loss: 0.8574, Constraint Loss: 2.9926
# Epoch [2430/10000], Loss: 0.7860, Constraint Loss: 3.0034
# Epoch [2440/10000], Loss: 0.7000, Constraint Loss: 2.5613
# Epoch [2450/10000], Loss: 0.8055, Constraint Loss: 3.2546
# Epoch [2460/10000], Loss: 0.7206, Constraint Loss: 2.4862
# Epoch [2470/10000], Loss: 0.8177, Constraint Loss: 2.7188
# Epoch [2480/10000], Loss: 0.8092, Constraint Loss: 2.4950
# Epoch [2490/10000], Loss: 0.9135, Constraint Loss: 2.4451
# Epoch [2500/10000], Loss: 0.9750, Constraint Loss: 2.9887
# Epoch [2510/10000], Loss: 0.7650, Constraint Loss: 2.8785
# Epoch [2520/10000], Loss: 0.6875, Constraint Loss: 2.4088
# Epoch [2530/10000], Loss: 0.7264, Constraint Loss: 2.7019
# Epoch [2540/10000], Loss: 0.7976, Constraint Loss: 2.7471
# Epoch [2550/10000], Loss: 0.6905, Constraint Loss: 2.8908
# Epoch [2560/10000], Loss: 0.8586, Constraint Loss: 2.4916
# Epoch [2570/10000], Loss: 0.6996, Constraint Loss: 2.6312
# Epoch [2580/10000], Loss: 0.6662, Constraint Loss: 2.7474
# Epoch [2590/10000], Loss: 0.6298, Constraint Loss: 2.5080
# Epoch [2600/10000], Loss: 0.6021, Constraint Loss: 2.7744
# Epoch [2610/10000], Loss: 0.8904, Constraint Loss: 3.3346
# Epoch [2620/10000], Loss: 0.6317, Constraint Loss: 2.8313
# Epoch [2630/10000], Loss: 0.6444, Constraint Loss: 2.7464
# Epoch [2640/10000], Loss: 0.6523, Constraint Loss: 2.3412
# Epoch [2650/10000], Loss: 0.6767, Constraint Loss: 2.3590
# Epoch [2660/10000], Loss: 0.6857, Constraint Loss: 2.4715
# Epoch [2670/10000], Loss: 0.6333, Constraint Loss: 2.2992
# Epoch [2680/10000], Loss: 0.6351, Constraint Loss: 2.3527
# Epoch [2690/10000], Loss: 0.6506, Constraint Loss: 2.3437
# Epoch [2700/10000], Loss: 0.6102, Constraint Loss: 2.3862
# Epoch [2710/10000], Loss: 0.5965, Constraint Loss: 2.6938
# Epoch [2720/10000], Loss: 0.7694, Constraint Loss: 3.3400
# Epoch [2730/10000], Loss: 0.9063, Constraint Loss: 2.7311
# Epoch [2740/10000], Loss: 0.7307, Constraint Loss: 3.2228
# Epoch [2750/10000], Loss: 0.7178, Constraint Loss: 2.7165
# Epoch [2760/10000], Loss: 0.7223, Constraint Loss: 3.5426
# Epoch [2770/10000], Loss: 0.6336, Constraint Loss: 2.9918
# Epoch [2780/10000], Loss: 0.6289, Constraint Loss: 3.0840
# Epoch [2790/10000], Loss: 0.6691, Constraint Loss: 2.9208
# Epoch [2800/10000], Loss: 0.6034, Constraint Loss: 2.9672
# Epoch [2810/10000], Loss: 0.6940, Constraint Loss: 2.7262
# Epoch [2820/10000], Loss: 0.7026, Constraint Loss: 2.9937
# Epoch [2830/10000], Loss: 0.8381, Constraint Loss: 3.5333
# Epoch [2840/10000], Loss: 0.6152, Constraint Loss: 2.7500
# Epoch [2850/10000], Loss: 0.6231, Constraint Loss: 2.5201
# Epoch [2860/10000], Loss: 0.5795, Constraint Loss: 2.7228
# Epoch [2870/10000], Loss: 0.6545, Constraint Loss: 2.2146
# Epoch [2880/10000], Loss: 0.9737, Constraint Loss: 2.5094
# Epoch [2890/10000], Loss: 0.5432, Constraint Loss: 2.5666
# Epoch [2900/10000], Loss: 0.6877, Constraint Loss: 3.3332
# Epoch [2910/10000], Loss: 0.7268, Constraint Loss: 2.8790
# Epoch [2920/10000], Loss: 0.8305, Constraint Loss: 3.0513
# Epoch [2930/10000], Loss: 0.8258, Constraint Loss: 3.7551
# Epoch [2940/10000], Loss: 0.6890, Constraint Loss: 3.8233
# Epoch [2950/10000], Loss: 0.6435, Constraint Loss: 3.4609
# Epoch [2960/10000], Loss: 0.6121, Constraint Loss: 3.3797
# Epoch [2970/10000], Loss: 0.6536, Constraint Loss: 3.5646
# Epoch [2980/10000], Loss: 0.6332, Constraint Loss: 3.7404
# Epoch [2990/10000], Loss: 0.7341, Constraint Loss: 3.3360
# Epoch [3000/10000], Loss: 0.6073, Constraint Loss: 3.6693
# Epoch [3010/10000], Loss: 0.7055, Constraint Loss: 3.7376
# Epoch [3020/10000], Loss: 0.5918, Constraint Loss: 3.5116
# Epoch [3030/10000], Loss: 0.6955, Constraint Loss: 3.8724
# Epoch [3040/10000], Loss: 0.6265, Constraint Loss: 2.9151
# Epoch [3050/10000], Loss: 0.5646, Constraint Loss: 3.0661
# Epoch [3060/10000], Loss: 0.6551, Constraint Loss: 3.2252
# Epoch [3070/10000], Loss: 0.6810, Constraint Loss: 3.1419
# Epoch [3080/10000], Loss: 0.8147, Constraint Loss: 4.1271
# Epoch [3090/10000], Loss: 0.6437, Constraint Loss: 3.3265
# Epoch [3100/10000], Loss: 0.6048, Constraint Loss: 2.9211
# Epoch [3110/10000], Loss: 0.6969, Constraint Loss: 2.8450
# Epoch [3120/10000], Loss: 0.7242, Constraint Loss: 2.9778
# Epoch [3130/10000], Loss: 0.6320, Constraint Loss: 3.1800
# Epoch [3140/10000], Loss: 0.6918, Constraint Loss: 3.0904
# Epoch [3150/10000], Loss: 0.6415, Constraint Loss: 2.9581
# Epoch [3160/10000], Loss: 0.5868, Constraint Loss: 2.7880
# Epoch [3170/10000], Loss: 0.6330, Constraint Loss: 3.3324
# Epoch [3180/10000], Loss: 0.5509, Constraint Loss: 2.9201
# Epoch [3190/10000], Loss: 0.5655, Constraint Loss: 3.2504
# Epoch [3200/10000], Loss: 0.6663, Constraint Loss: 2.9279
# Epoch [3210/10000], Loss: 0.6156, Constraint Loss: 2.7528
# Epoch [3220/10000], Loss: 0.6527, Constraint Loss: 2.9096
# Epoch [3230/10000], Loss: 0.6481, Constraint Loss: 3.0642
# Epoch [3240/10000], Loss: 0.7784, Constraint Loss: 3.3099
# Epoch [3250/10000], Loss: 0.6961, Constraint Loss: 3.0402
# Epoch [3260/10000], Loss: 0.6714, Constraint Loss: 2.8225
# Epoch [3270/10000], Loss: 0.6153, Constraint Loss: 2.6553
# Epoch [3280/10000], Loss: 0.6105, Constraint Loss: 2.6137
# Epoch [3290/10000], Loss: 0.5754, Constraint Loss: 2.4896
# Epoch [3300/10000], Loss: 0.6027, Constraint Loss: 2.5806
# Epoch [3310/10000], Loss: 0.5469, Constraint Loss: 2.5306
# Epoch [3320/10000], Loss: 0.6262, Constraint Loss: 2.7484
# Epoch [3330/10000], Loss: 0.6740, Constraint Loss: 2.6067
# Epoch [3340/10000], Loss: 0.6570, Constraint Loss: 2.1911
# Epoch [3350/10000], Loss: 0.6167, Constraint Loss: 2.0157
# Epoch [3360/10000], Loss: 0.6313, Constraint Loss: 2.2261
# Epoch [3370/10000], Loss: 0.6259, Constraint Loss: 2.2206
# Epoch [3380/10000], Loss: 0.5932, Constraint Loss: 2.1520
# Epoch [3390/10000], Loss: 0.5966, Constraint Loss: 2.3395
# Epoch [3400/10000], Loss: 0.5986, Constraint Loss: 2.7270
# Epoch [3410/10000], Loss: 0.6429, Constraint Loss: 3.0235
# Epoch [3420/10000], Loss: 0.7588, Constraint Loss: 3.4226
# Epoch [3430/10000], Loss: 0.6544, Constraint Loss: 3.0847
# Epoch [3440/10000], Loss: 0.5168, Constraint Loss: 3.2072
# Epoch [3450/10000], Loss: 0.5451, Constraint Loss: 2.8319
# Epoch [3460/10000], Loss: 0.6803, Constraint Loss: 3.3245
# Epoch [3470/10000], Loss: 0.5713, Constraint Loss: 4.5233
# Epoch [3480/10000], Loss: 0.6414, Constraint Loss: 3.5905
# Epoch [3490/10000], Loss: 0.4769, Constraint Loss: 2.9804
# Epoch [3500/10000], Loss: 0.5002, Constraint Loss: 2.7094
# Epoch [3510/10000], Loss: 0.7107, Constraint Loss: 2.7120
# Epoch [3520/10000], Loss: 0.5418, Constraint Loss: 2.7260
# Epoch [3530/10000], Loss: 0.5686, Constraint Loss: 2.4726
# Epoch [3540/10000], Loss: 0.6247, Constraint Loss: 2.0035
# Epoch [3550/10000], Loss: 0.6956, Constraint Loss: 1.9632
# Epoch [3560/10000], Loss: 0.8506, Constraint Loss: 1.7906
# Epoch [3570/10000], Loss: 0.7124, Constraint Loss: 1.7477
# Epoch [3580/10000], Loss: 0.6079, Constraint Loss: 1.9035
# Epoch [3590/10000], Loss: 0.7548, Constraint Loss: 1.6940
# Epoch [3600/10000], Loss: 0.6446, Constraint Loss: 1.7985
# Epoch [3610/10000], Loss: 0.6537, Constraint Loss: 2.3419
# Epoch [3620/10000], Loss: 0.7684, Constraint Loss: 1.8827
# Epoch [3630/10000], Loss: 0.5961, Constraint Loss: 2.2226
# Epoch [3640/10000], Loss: 0.6118, Constraint Loss: 2.0950
# Epoch [3650/10000], Loss: 0.6120, Constraint Loss: 1.9413
# Epoch [3660/10000], Loss: 0.6461, Constraint Loss: 1.9724
# Epoch [3670/10000], Loss: 0.8237, Constraint Loss: 1.5183
# Epoch [3680/10000], Loss: 0.7261, Constraint Loss: 1.6588
# Epoch [3690/10000], Loss: 0.7969, Constraint Loss: 2.2425
# Epoch [3700/10000], Loss: 2.1161, Constraint Loss: 2.5762
# Epoch [3710/10000], Loss: 0.7782, Constraint Loss: 2.8108
# Epoch [3720/10000], Loss: 0.6808, Constraint Loss: 2.3929
# Epoch [3730/10000], Loss: 1.1092, Constraint Loss: 3.6503
# Epoch [3740/10000], Loss: 0.7066, Constraint Loss: 2.7684
# Epoch [3750/10000], Loss: 0.9935, Constraint Loss: 2.3010
# Epoch [3760/10000], Loss: 0.6629, Constraint Loss: 2.3849
# Epoch [3770/10000], Loss: 1.4736, Constraint Loss: 3.2869
# Epoch [3780/10000], Loss: 0.7496, Constraint Loss: 2.4707
# Epoch [3790/10000], Loss: 0.7297, Constraint Loss: 2.8606
# Epoch [3800/10000], Loss: 0.7411, Constraint Loss: 2.4220
# Epoch [3810/10000], Loss: 0.7492, Constraint Loss: 2.2166
# Epoch [3820/10000], Loss: 0.7050, Constraint Loss: 2.4482
# Epoch [3830/10000], Loss: 0.6693, Constraint Loss: 2.4404
# Epoch [3840/10000], Loss: 0.8432, Constraint Loss: 3.2251
# Epoch [3850/10000], Loss: 0.8560, Constraint Loss: 2.4472
# Epoch [3860/10000], Loss: 0.8528, Constraint Loss: 2.4462
# Epoch [3870/10000], Loss: 1.2963, Constraint Loss: 4.5212
# Epoch [3880/10000], Loss: 2.2098, Constraint Loss: 11.5716
# Epoch [3890/10000], Loss: 1.0339, Constraint Loss: 2.7144
# Epoch [3900/10000], Loss: 0.9299, Constraint Loss: 2.1646
# Epoch [3910/10000], Loss: 0.9894, Constraint Loss: 1.9528
# Epoch [3920/10000], Loss: 0.8816, Constraint Loss: 1.7684
# Epoch [3930/10000], Loss: 0.9202, Constraint Loss: 1.7923
# Epoch [3940/10000], Loss: 0.8781, Constraint Loss: 1.5664
# Epoch [3950/10000], Loss: 0.8127, Constraint Loss: 1.8219
# Epoch [3960/10000], Loss: 0.7823, Constraint Loss: 1.9560
# Epoch [3970/10000], Loss: 0.9279, Constraint Loss: 1.5925
# Epoch [3980/10000], Loss: 0.8429, Constraint Loss: 2.4762
# Epoch [3990/10000], Loss: 0.8222, Constraint Loss: 1.9039
# Epoch [4000/10000], Loss: 0.8675, Constraint Loss: 1.9591
# Epoch [4010/10000], Loss: 2.4569, Constraint Loss: 2.6702
# Epoch [4020/10000], Loss: 0.8932, Constraint Loss: 2.5084
# Epoch [4030/10000], Loss: 1.0414, Constraint Loss: 2.2362
# Epoch [4040/10000], Loss: 0.8601, Constraint Loss: 2.9403
# Epoch [4050/10000], Loss: 0.8299, Constraint Loss: 1.7805
# Epoch [4060/10000], Loss: 0.8134, Constraint Loss: 1.6801
# Epoch [4070/10000], Loss: 0.9807, Constraint Loss: 2.6047
# Epoch [4080/10000], Loss: 0.9455, Constraint Loss: 1.8622
# Epoch [4090/10000], Loss: 0.9286, Constraint Loss: 1.6678
# Epoch [4100/10000], Loss: 0.9126, Constraint Loss: 1.4630
# Epoch [4110/10000], Loss: 0.8775, Constraint Loss: 1.4163
# Epoch [4120/10000], Loss: 0.8802, Constraint Loss: 1.2402
# Epoch [4130/10000], Loss: 0.9473, Constraint Loss: 1.2789
# Epoch [4140/10000], Loss: 0.8914, Constraint Loss: 1.2312
# Epoch [4150/10000], Loss: 1.0499, Constraint Loss: 1.4486
# Epoch [4160/10000], Loss: 0.8718, Constraint Loss: 1.5863
# Epoch [4170/10000], Loss: 1.0545, Constraint Loss: 1.6761
# Epoch [4180/10000], Loss: 0.9587, Constraint Loss: 1.7402
# Epoch [4190/10000], Loss: 1.0776, Constraint Loss: 1.8138
# Epoch [4200/10000], Loss: 0.9379, Constraint Loss: 2.1525
# Epoch [4210/10000], Loss: 0.8855, Constraint Loss: 2.0116
# Epoch [4220/10000], Loss: 0.8946, Constraint Loss: 2.2355
# Epoch [4230/10000], Loss: 0.8524, Constraint Loss: 1.4446
# Epoch [4240/10000], Loss: 0.8348, Constraint Loss: 1.3665
# Epoch [4250/10000], Loss: 0.8463, Constraint Loss: 1.6177
# Epoch [4260/10000], Loss: 0.8321, Constraint Loss: 1.9534
# Epoch [4270/10000], Loss: 0.8841, Constraint Loss: 1.5522
# Epoch [4280/10000], Loss: 0.8441, Constraint Loss: 1.9672
# Epoch [4290/10000], Loss: 0.8174, Constraint Loss: 1.8405
# Epoch [4300/10000], Loss: 0.8698, Constraint Loss: 1.6258
# Epoch [4310/10000], Loss: 0.8023, Constraint Loss: 1.4120
# Epoch [4320/10000], Loss: 0.9294, Constraint Loss: 1.8843
# Epoch [4330/10000], Loss: 0.8495, Constraint Loss: 1.8544
# Epoch [4340/10000], Loss: 0.8845, Constraint Loss: 2.8539
# Epoch [4350/10000], Loss: 0.8946, Constraint Loss: 2.4549
# Epoch [4360/10000], Loss: 0.8807, Constraint Loss: 1.7347
# Epoch [4370/10000], Loss: 0.8499, Constraint Loss: 1.2245
# Epoch [4380/10000], Loss: 1.0536, Constraint Loss: 1.2290
# Epoch [4390/10000], Loss: 0.8693, Constraint Loss: 1.0199
# Epoch [4400/10000], Loss: 0.8606, Constraint Loss: 1.6264
# Epoch [4410/10000], Loss: 0.8236, Constraint Loss: 1.5550
# Epoch [4420/10000], Loss: 1.3403, Constraint Loss: 1.8895
# Epoch [4430/10000], Loss: 0.9623, Constraint Loss: 1.4129
# Epoch [4440/10000], Loss: 0.9207, Constraint Loss: 1.3720
# Epoch [4450/10000], Loss: 0.8077, Constraint Loss: 1.3105
# Epoch [4460/10000], Loss: 0.8499, Constraint Loss: 1.2830
# Epoch [4470/10000], Loss: 1.0098, Constraint Loss: 1.5070
# Epoch [4480/10000], Loss: 0.9859, Constraint Loss: 1.5598
# Epoch [4490/10000], Loss: 0.9423, Constraint Loss: 1.3836
# Epoch [4500/10000], Loss: 0.9687, Constraint Loss: 1.3213
# Epoch [4510/10000], Loss: 0.9064, Constraint Loss: 1.1073
# Epoch [4520/10000], Loss: 0.9152, Constraint Loss: 1.0333
# Epoch [4530/10000], Loss: 0.9101, Constraint Loss: 1.0434
# Epoch [4540/10000], Loss: 0.8552, Constraint Loss: 1.9503
# Epoch [4550/10000], Loss: 0.8857, Constraint Loss: 1.3981
# Epoch [4560/10000], Loss: 0.8966, Constraint Loss: 1.9970
# Epoch [4570/10000], Loss: 0.8392, Constraint Loss: 1.4988
# Epoch [4580/10000], Loss: 0.9133, Constraint Loss: 1.5914
# Epoch [4590/10000], Loss: 0.7805, Constraint Loss: 1.5365
# Epoch [4600/10000], Loss: 0.7976, Constraint Loss: 1.2123
# Epoch [4610/10000], Loss: 1.1268, Constraint Loss: 4.3294
# Epoch [4620/10000], Loss: 0.8424, Constraint Loss: 2.0149
# Epoch [4630/10000], Loss: 0.8575, Constraint Loss: 1.8953
# Epoch [4640/10000], Loss: 0.8519, Constraint Loss: 2.0664
# Epoch [4650/10000], Loss: 0.7947, Constraint Loss: 1.7842
# Epoch [4660/10000], Loss: 0.7682, Constraint Loss: 1.6297
# Epoch [4670/10000], Loss: 0.8034, Constraint Loss: 1.9147
# Epoch [4680/10000], Loss: 0.8550, Constraint Loss: 1.8086
# Epoch [4690/10000], Loss: 0.8456, Constraint Loss: 1.4725
# Epoch [4700/10000], Loss: 0.9088, Constraint Loss: 1.4667
# Epoch [4710/10000], Loss: 0.8729, Constraint Loss: 1.4367
# Epoch [4720/10000], Loss: 0.8354, Constraint Loss: 1.4656
# Epoch [4730/10000], Loss: 0.7391, Constraint Loss: 1.6372
# Epoch [4740/10000], Loss: 0.7415, Constraint Loss: 1.9827
# Epoch [4750/10000], Loss: 0.6780, Constraint Loss: 1.8116
# Epoch [4760/10000], Loss: 0.8203, Constraint Loss: 1.8892
# Epoch [4770/10000], Loss: 0.7820, Constraint Loss: 2.3278
# Epoch [4780/10000], Loss: 0.7121, Constraint Loss: 1.6048
# Epoch [4790/10000], Loss: 0.7186, Constraint Loss: 1.3510
# Epoch [4800/10000], Loss: 0.7613, Constraint Loss: 1.5450
# Epoch [4810/10000], Loss: 0.7859, Constraint Loss: 1.4565
# Epoch [4820/10000], Loss: 0.8545, Constraint Loss: 2.4588
# Epoch [4830/10000], Loss: 0.6619, Constraint Loss: 1.5014
# Epoch [4840/10000], Loss: 0.7238, Constraint Loss: 2.0728
# Epoch [4850/10000], Loss: 0.9852, Constraint Loss: 4.3941
# Epoch [4860/10000], Loss: 0.7840, Constraint Loss: 3.6689
# Epoch [4870/10000], Loss: 0.6986, Constraint Loss: 2.8256
# Epoch [4880/10000], Loss: 0.6649, Constraint Loss: 2.4582
# Epoch [4890/10000], Loss: 0.9588, Constraint Loss: 4.1114
# Epoch [4900/10000], Loss: 0.8557, Constraint Loss: 3.2945
# Epoch [4910/10000], Loss: 0.8478, Constraint Loss: 3.4628
# Epoch [4920/10000], Loss: 0.7757, Constraint Loss: 5.3000
# Epoch [4930/10000], Loss: 0.7417, Constraint Loss: 4.2403
# Epoch [4940/10000], Loss: 0.7796, Constraint Loss: 5.6773
# Epoch [4950/10000], Loss: 0.9768, Constraint Loss: 5.1942
# Epoch [4960/10000], Loss: 0.8259, Constraint Loss: 3.6168
# Epoch [4970/10000], Loss: 0.7606, Constraint Loss: 2.9309
# Epoch [4980/10000], Loss: 0.9004, Constraint Loss: 3.6132
# Epoch [4990/10000], Loss: 0.8137, Constraint Loss: 4.9308
# Epoch [5000/10000], Loss: 1.2394, Constraint Loss: 14.8551
# Epoch [5010/10000], Loss: 0.9124, Constraint Loss: 4.4482
# Epoch [5020/10000], Loss: 0.8419, Constraint Loss: 3.4081
# Epoch [5030/10000], Loss: 0.8369, Constraint Loss: 3.1584
# Epoch [5040/10000], Loss: 0.8037, Constraint Loss: 2.8222
# Epoch [5050/10000], Loss: 0.8853, Constraint Loss: 3.2047
# Epoch [5060/10000], Loss: 0.8183, Constraint Loss: 3.4279
# Epoch [5070/10000], Loss: 0.7129, Constraint Loss: 3.0466
# Epoch [5080/10000], Loss: 0.7607, Constraint Loss: 3.1491
# Epoch [5090/10000], Loss: 0.7095, Constraint Loss: 5.3804
# Epoch [5100/10000], Loss: 0.6615, Constraint Loss: 3.9007
# Epoch [5110/10000], Loss: 0.7216, Constraint Loss: 4.0190
# Epoch [5120/10000], Loss: 0.7297, Constraint Loss: 4.3991
# Epoch [5130/10000], Loss: 0.6461, Constraint Loss: 3.6669
# Epoch [5140/10000], Loss: 0.7224, Constraint Loss: 4.0540
# Epoch [5150/10000], Loss: 0.6608, Constraint Loss: 3.6642
# Epoch [5160/10000], Loss: 0.6705, Constraint Loss: 4.6298
# Epoch [5170/10000], Loss: 0.6818, Constraint Loss: 4.2057
# Epoch [5180/10000], Loss: 0.6767, Constraint Loss: 3.2593
# Epoch [5190/10000], Loss: 0.6588, Constraint Loss: 2.6927
# Epoch [5200/10000], Loss: 0.6295, Constraint Loss: 2.9957
# Epoch [5210/10000], Loss: 0.6244, Constraint Loss: 2.9285
# Epoch [5220/10000], Loss: 1.5162, Constraint Loss: 3.8441
# Epoch [5230/10000], Loss: 0.6974, Constraint Loss: 3.9891
# Epoch [5240/10000], Loss: 0.6836, Constraint Loss: 4.1262
# Epoch [5250/10000], Loss: 0.7474, Constraint Loss: 3.6219
# Epoch [5260/10000], Loss: 0.8262, Constraint Loss: 3.8668
# Epoch [5270/10000], Loss: 0.7165, Constraint Loss: 4.6582
# Epoch [5280/10000], Loss: 0.6386, Constraint Loss: 3.9352
# Epoch [5290/10000], Loss: 0.6596, Constraint Loss: 3.3579
# Epoch [5300/10000], Loss: 0.7321, Constraint Loss: 3.1011
# Epoch [5310/10000], Loss: 0.6305, Constraint Loss: 2.6864
# Epoch [5320/10000], Loss: 0.6266, Constraint Loss: 2.7543
# Epoch [5330/10000], Loss: 0.7001, Constraint Loss: 2.3946
# Epoch [5340/10000], Loss: 0.6900, Constraint Loss: 3.0230
# Epoch [5350/10000], Loss: 0.6509, Constraint Loss: 5.1315
# Epoch [5360/10000], Loss: 0.6308, Constraint Loss: 3.7057
# Epoch [5370/10000], Loss: 0.6675, Constraint Loss: 3.3126
# Epoch [5380/10000], Loss: 0.7962, Constraint Loss: 3.5529
# Epoch [5390/10000], Loss: 0.6555, Constraint Loss: 3.3686
# Epoch [5400/10000], Loss: 0.6780, Constraint Loss: 2.6180
# Epoch [5410/10000], Loss: 0.8439, Constraint Loss: 3.5658
# Epoch [5420/10000], Loss: 0.6172, Constraint Loss: 2.6326
# Epoch [5430/10000], Loss: 0.7686, Constraint Loss: 4.3614
# Epoch [5440/10000], Loss: 0.6394, Constraint Loss: 3.0558
# Epoch [5450/10000], Loss: 0.7540, Constraint Loss: 4.6938
# Epoch [5460/10000], Loss: 0.6622, Constraint Loss: 3.2096
# Epoch [5470/10000], Loss: 1.3401, Constraint Loss: 3.5383
# Epoch [5480/10000], Loss: 0.6778, Constraint Loss: 3.1204
# Epoch [5490/10000], Loss: 0.7009, Constraint Loss: 2.5319
# Epoch [5500/10000], Loss: 0.6431, Constraint Loss: 2.8087
# Epoch [5510/10000], Loss: 0.7386, Constraint Loss: 2.5923
# Epoch [5520/10000], Loss: 0.7398, Constraint Loss: 2.4819
# Epoch [5530/10000], Loss: 0.8112, Constraint Loss: 2.3918
# Epoch [5540/10000], Loss: 0.8284, Constraint Loss: 3.7486
# Epoch [5550/10000], Loss: 0.9511, Constraint Loss: 6.1483
# Epoch [5560/10000], Loss: 0.8122, Constraint Loss: 3.9463
# Epoch [5570/10000], Loss: 0.6770, Constraint Loss: 3.5497
# Epoch [5580/10000], Loss: 0.7247, Constraint Loss: 3.4620
# Epoch [5590/10000], Loss: 0.7938, Constraint Loss: 3.2444
# Epoch [5600/10000], Loss: 0.7465, Constraint Loss: 3.0229
# Epoch [5610/10000], Loss: 0.7635, Constraint Loss: 3.4480
# Epoch [5620/10000], Loss: 0.7986, Constraint Loss: 4.3735
# Epoch [5630/10000], Loss: 0.8313, Constraint Loss: 4.6171
# Epoch [5640/10000], Loss: 0.9248, Constraint Loss: 5.3739
# Epoch [5650/10000], Loss: 0.7898, Constraint Loss: 4.1337
# Epoch [5660/10000], Loss: 0.8219, Constraint Loss: 4.0823
# Epoch [5670/10000], Loss: 1.3579, Constraint Loss: 6.0743
# Epoch [5680/10000], Loss: 0.9072, Constraint Loss: 4.6085
# Epoch [5690/10000], Loss: 0.9077, Constraint Loss: 4.5058
# Epoch [5700/10000], Loss: 0.8782, Constraint Loss: 3.7641
# Epoch [5710/10000], Loss: 0.7792, Constraint Loss: 3.8272
# Epoch [5720/10000], Loss: 0.8256, Constraint Loss: 4.0764
# Epoch [5730/10000], Loss: 0.7947, Constraint Loss: 4.2710
# Epoch [5740/10000], Loss: 0.9856, Constraint Loss: 4.5828
# Epoch [5750/10000], Loss: 0.9690, Constraint Loss: 4.8796
# Epoch [5760/10000], Loss: 0.7625, Constraint Loss: 4.2122
# Epoch [5770/10000], Loss: 1.2876, Constraint Loss: 4.4720
# Epoch [5780/10000], Loss: 0.7414, Constraint Loss: 4.4600
# Epoch [5790/10000], Loss: 0.7594, Constraint Loss: 3.9013
# Epoch [5800/10000], Loss: 0.7560, Constraint Loss: 3.9753
# Epoch [5810/10000], Loss: 0.8637, Constraint Loss: 3.9443
# Epoch [5820/10000], Loss: 0.7648, Constraint Loss: 4.0045
# Epoch [5830/10000], Loss: 0.7986, Constraint Loss: 4.1168
# Epoch [5840/10000], Loss: 0.7595, Constraint Loss: 4.7643
# Epoch [5850/10000], Loss: 0.7521, Constraint Loss: 4.7841
# Epoch [5860/10000], Loss: 0.8478, Constraint Loss: 4.4805
# Epoch [5870/10000], Loss: 0.7590, Constraint Loss: 4.1846
# Epoch [5880/10000], Loss: 0.8295, Constraint Loss: 7.1002
# Epoch [5890/10000], Loss: 0.7169, Constraint Loss: 5.3985
# Epoch [5900/10000], Loss: 0.6868, Constraint Loss: 4.9197
# Epoch [5910/10000], Loss: 2.2668, Constraint Loss: 6.0243
# Epoch [5920/10000], Loss: 0.7321, Constraint Loss: 6.8506
# Epoch [5930/10000], Loss: 0.7086, Constraint Loss: 7.1364
# Epoch [5940/10000], Loss: 0.7172, Constraint Loss: 7.1414
# Epoch [5950/10000], Loss: 0.8630, Constraint Loss: 6.8383
# Epoch [5960/10000], Loss: 0.6363, Constraint Loss: 5.8948
# Epoch [5970/10000], Loss: 0.7153, Constraint Loss: 5.8700
# Epoch [5980/10000], Loss: 0.7769, Constraint Loss: 7.5276
# Epoch [5990/10000], Loss: 0.7920, Constraint Loss: 6.0012
# Epoch [6000/10000], Loss: 0.9331, Constraint Loss: 6.4219
# Epoch [6010/10000], Loss: 1.0628, Constraint Loss: 7.0343
# Epoch [6020/10000], Loss: 0.8519, Constraint Loss: 6.1452
# Epoch [6030/10000], Loss: 1.0324, Constraint Loss: 6.2557
# Epoch [6040/10000], Loss: 0.7215, Constraint Loss: 5.5320
# Epoch [6050/10000], Loss: 0.6849, Constraint Loss: 4.6034
# Epoch [6060/10000], Loss: 0.6795, Constraint Loss: 4.9800
# Epoch [6070/10000], Loss: 0.8013, Constraint Loss: 4.9617
# Epoch [6080/10000], Loss: 0.6515, Constraint Loss: 5.5588
# Epoch [6090/10000], Loss: 1.3784, Constraint Loss: 7.1996
# Epoch [6100/10000], Loss: 0.5925, Constraint Loss: 5.1652
# Epoch [6110/10000], Loss: 0.6242, Constraint Loss: 5.5171
# Epoch [6120/10000], Loss: 0.6717, Constraint Loss: 4.7742
# Epoch [6130/10000], Loss: 1.1832, Constraint Loss: 5.2977
# Epoch [6140/10000], Loss: 0.6072, Constraint Loss: 6.3798
# Epoch [6150/10000], Loss: 1.1833, Constraint Loss: 8.8035
# Epoch [6160/10000], Loss: 0.7169, Constraint Loss: 6.3977
# Epoch [6170/10000], Loss: 1.0109, Constraint Loss: 5.9534
# Epoch [6180/10000], Loss: 0.6159, Constraint Loss: 5.7926
# Epoch [6190/10000], Loss: 0.6371, Constraint Loss: 5.6117
# Epoch [6200/10000], Loss: 0.7397, Constraint Loss: 6.6287
# Epoch [6210/10000], Loss: 0.6941, Constraint Loss: 6.9715
# Epoch [6220/10000], Loss: 1.1416, Constraint Loss: 10.5468
# Epoch [6230/10000], Loss: 0.7942, Constraint Loss: 10.6616
# Epoch [6240/10000], Loss: 0.6575, Constraint Loss: 6.4340
# Epoch [6250/10000], Loss: 0.5903, Constraint Loss: 6.1894
# Epoch [6260/10000], Loss: 0.5873, Constraint Loss: 6.3405
# Epoch [6270/10000], Loss: 0.6599, Constraint Loss: 6.0352
# Epoch [6280/10000], Loss: 0.6649, Constraint Loss: 5.5702
# Epoch [6290/10000], Loss: 0.5548, Constraint Loss: 4.7629
# Epoch [6300/10000], Loss: 0.5708, Constraint Loss: 4.8740
# Epoch [6310/10000], Loss: 0.5817, Constraint Loss: 4.4841
# Epoch [6320/10000], Loss: 0.6386, Constraint Loss: 4.9478
# Epoch [6330/10000], Loss: 0.6330, Constraint Loss: 4.6638
# Epoch [6340/10000], Loss: 0.5886, Constraint Loss: 4.5447
# Epoch [6350/10000], Loss: 0.5382, Constraint Loss: 4.0536
# Epoch [6360/10000], Loss: 0.6481, Constraint Loss: 4.2383
# Epoch [6370/10000], Loss: 0.6094, Constraint Loss: 4.4855
# Epoch [6380/10000], Loss: 0.5967, Constraint Loss: 4.6684
# Epoch [6390/10000], Loss: 0.5793, Constraint Loss: 4.6189
# Epoch [6400/10000], Loss: 0.6183, Constraint Loss: 4.2597
# Epoch [6410/10000], Loss: 0.5741, Constraint Loss: 4.3539
# Epoch [6420/10000], Loss: 0.5530, Constraint Loss: 3.8191
# Epoch [6430/10000], Loss: 0.5548, Constraint Loss: 4.2372
# Epoch [6440/10000], Loss: 0.6261, Constraint Loss: 4.0306
# Epoch [6450/10000], Loss: 1.6520, Constraint Loss: 4.0590
# Epoch [6460/10000], Loss: 0.5448, Constraint Loss: 4.9783
# Epoch [6470/10000], Loss: 0.5838, Constraint Loss: 4.2070
# Epoch [6480/10000], Loss: 1.5869, Constraint Loss: 4.9684
# Epoch [6490/10000], Loss: 0.5680, Constraint Loss: 4.4905
# Epoch [6500/10000], Loss: 0.5815, Constraint Loss: 3.8610
# Epoch [6510/10000], Loss: 0.6189, Constraint Loss: 5.1579
# Epoch [6520/10000], Loss: 0.5941, Constraint Loss: 4.7606
# Epoch [6530/10000], Loss: 0.5549, Constraint Loss: 4.1123
# Epoch [6540/10000], Loss: 0.8710, Constraint Loss: 8.0651
# Epoch [6550/10000], Loss: 0.5600, Constraint Loss: 4.6589
# Epoch [6560/10000], Loss: 0.6219, Constraint Loss: 4.3662
# Epoch [6570/10000], Loss: 0.5665, Constraint Loss: 4.4079
# Epoch [6580/10000], Loss: 0.5699, Constraint Loss: 5.1730
# Epoch [6590/10000], Loss: 0.5504, Constraint Loss: 5.7692
# Epoch [6600/10000], Loss: 0.6923, Constraint Loss: 5.7415
# Epoch [6610/10000], Loss: 0.6925, Constraint Loss: 4.5255
# Epoch [6620/10000], Loss: 0.6140, Constraint Loss: 5.2521
# Epoch [6630/10000], Loss: 0.5417, Constraint Loss: 4.9722
# Epoch [6640/10000], Loss: 0.6117, Constraint Loss: 5.7909
# Epoch [6650/10000], Loss: 0.7126, Constraint Loss: 5.1517
# Epoch [6660/10000], Loss: 0.5661, Constraint Loss: 5.5159
# Epoch [6670/10000], Loss: 0.5865, Constraint Loss: 5.9726
# Epoch [6680/10000], Loss: 0.6267, Constraint Loss: 4.8426
# Epoch [6690/10000], Loss: 0.5629, Constraint Loss: 7.4804
# Epoch [6700/10000], Loss: 0.6682, Constraint Loss: 4.8012
# Epoch [6710/10000], Loss: 0.5454, Constraint Loss: 4.2756
# Epoch [6720/10000], Loss: 0.6238, Constraint Loss: 4.2116
# Epoch [6730/10000], Loss: 0.5472, Constraint Loss: 3.9775
# Epoch [6740/10000], Loss: 0.7263, Constraint Loss: 3.8949
# Epoch [6750/10000], Loss: 0.7157, Constraint Loss: 5.5941
# Epoch [6760/10000], Loss: 0.5543, Constraint Loss: 4.1159
# Epoch [6770/10000], Loss: 0.6131, Constraint Loss: 3.8274
# Epoch [6780/10000], Loss: 0.6061, Constraint Loss: 4.2576
# Epoch [6790/10000], Loss: 0.6211, Constraint Loss: 4.9350
# Epoch [6800/10000], Loss: 2.3074, Constraint Loss: 9.1689
# Epoch [6810/10000], Loss: 1.7054, Constraint Loss: 7.1998
# Epoch [6820/10000], Loss: 1.7346, Constraint Loss: 7.4484
# Epoch [6830/10000], Loss: 1.2428, Constraint Loss: 6.9676
# Epoch [6840/10000], Loss: 1.2920, Constraint Loss: 6.7397
# Epoch [6850/10000], Loss: 1.1439, Constraint Loss: 6.9693
# Epoch [6860/10000], Loss: 1.1156, Constraint Loss: 6.9327
# Epoch [6870/10000], Loss: 1.1091, Constraint Loss: 7.4401
# Epoch [6880/10000], Loss: 1.1011, Constraint Loss: 5.9271
# Epoch [6890/10000], Loss: 1.2572, Constraint Loss: 6.2011
# Epoch [6900/10000], Loss: 1.0552, Constraint Loss: 7.3391
# Epoch [6910/10000], Loss: 1.0847, Constraint Loss: 6.0097
# Epoch [6920/10000], Loss: 1.0257, Constraint Loss: 6.5117
# Epoch [6930/10000], Loss: 0.9368, Constraint Loss: 5.2410
# Epoch [6940/10000], Loss: 0.9013, Constraint Loss: 5.2169
# Epoch [6950/10000], Loss: 0.9312, Constraint Loss: 5.8037
# Epoch [6960/10000], Loss: 0.9630, Constraint Loss: 5.5446
# Epoch [6970/10000], Loss: 1.1857, Constraint Loss: 6.1066
# Epoch [6980/10000], Loss: 0.9217, Constraint Loss: 4.9609
# Epoch [6990/10000], Loss: 1.0473, Constraint Loss: 5.0322
# Epoch [7000/10000], Loss: 1.0845, Constraint Loss: 5.8740
# Epoch [7010/10000], Loss: 0.8768, Constraint Loss: 4.1912
# Epoch [7020/10000], Loss: 0.9135, Constraint Loss: 3.3530
# Epoch [7030/10000], Loss: 1.1108, Constraint Loss: 4.1362
# Epoch [7040/10000], Loss: 0.9868, Constraint Loss: 4.4450
# Epoch [7050/10000], Loss: 0.9046, Constraint Loss: 4.0452
# Epoch [7060/10000], Loss: 0.8641, Constraint Loss: 3.8136
# Epoch [7070/10000], Loss: 0.8377, Constraint Loss: 3.4101
# Epoch [7080/10000], Loss: 0.8750, Constraint Loss: 4.1696
# Epoch [7090/10000], Loss: 0.9691, Constraint Loss: 4.2185
# Epoch [7100/10000], Loss: 0.8839, Constraint Loss: 3.5873
# Epoch [7110/10000], Loss: 0.9012, Constraint Loss: 3.3551
# Epoch [7120/10000], Loss: 0.9966, Constraint Loss: 2.8112
# Epoch [7130/10000], Loss: 0.8589, Constraint Loss: 2.6797
# Epoch [7140/10000], Loss: 1.0599, Constraint Loss: 3.1066
# Epoch [7150/10000], Loss: 0.9167, Constraint Loss: 3.1941
# Epoch [7160/10000], Loss: 0.9961, Constraint Loss: 3.4206
# Epoch [7170/10000], Loss: 0.9755, Constraint Loss: 3.2609
# Epoch [7180/10000], Loss: 1.0041, Constraint Loss: 3.2980
# Epoch [7190/10000], Loss: 0.9128, Constraint Loss: 3.6799
# Epoch [7200/10000], Loss: 0.8997, Constraint Loss: 3.9104
# Epoch [7210/10000], Loss: 0.9904, Constraint Loss: 3.6022
# Epoch [7220/10000], Loss: 0.9155, Constraint Loss: 3.8040
# Epoch [7230/10000], Loss: 1.0342, Constraint Loss: 3.5608
# Epoch [7240/10000], Loss: 0.9461, Constraint Loss: 2.7453
# Epoch [7250/10000], Loss: 0.9152, Constraint Loss: 2.7247
# Epoch [7260/10000], Loss: 0.8777, Constraint Loss: 2.4093
# Epoch [7270/10000], Loss: 0.8828, Constraint Loss: 2.8147
# Epoch [7280/10000], Loss: 0.8536, Constraint Loss: 2.7072
# Epoch [7290/10000], Loss: 0.8736, Constraint Loss: 2.2571
# Epoch [7300/10000], Loss: 0.9971, Constraint Loss: 2.2377
# Epoch [7310/10000], Loss: 0.8601, Constraint Loss: 2.3427
# Epoch [7320/10000], Loss: 0.9125, Constraint Loss: 2.5466
# Epoch [7330/10000], Loss: 0.8614, Constraint Loss: 2.3008
# Epoch [7340/10000], Loss: 0.8413, Constraint Loss: 2.3647
# Epoch [7350/10000], Loss: 0.7507, Constraint Loss: 2.2282
# Epoch [7360/10000], Loss: 0.7633, Constraint Loss: 2.1924
# Epoch [7370/10000], Loss: 0.7987, Constraint Loss: 1.9633
# Epoch [7380/10000], Loss: 0.7978, Constraint Loss: 2.0300
# Epoch [7390/10000], Loss: 0.8026, Constraint Loss: 1.8629
# Epoch [7400/10000], Loss: 0.8839, Constraint Loss: 3.4633
# Epoch [7410/10000], Loss: 0.7817, Constraint Loss: 2.3320
# Epoch [7420/10000], Loss: 0.8643, Constraint Loss: 2.5723
# Epoch [7430/10000], Loss: 0.8660, Constraint Loss: 2.5532
# Epoch [7440/10000], Loss: 3.2596, Constraint Loss: 3.1383
# Epoch [7450/10000], Loss: 1.1473, Constraint Loss: 3.8738
# Epoch [7460/10000], Loss: 1.0488, Constraint Loss: 3.4171
# Epoch [7470/10000], Loss: 1.1330, Constraint Loss: 2.9999
# Epoch [7480/10000], Loss: 0.9435, Constraint Loss: 2.5485
# Epoch [7490/10000], Loss: 1.1008, Constraint Loss: 2.5740
# Epoch [7500/10000], Loss: 0.8922, Constraint Loss: 2.1962
# Epoch [7510/10000], Loss: 0.9322, Constraint Loss: 1.8573
# Epoch [7520/10000], Loss: 0.8907, Constraint Loss: 1.8895
# Epoch [7530/10000], Loss: 1.0169, Constraint Loss: 2.0021
# Epoch [7540/10000], Loss: 0.8990, Constraint Loss: 2.1167
# Epoch [7550/10000], Loss: 0.8890, Constraint Loss: 1.8862
# Epoch [7560/10000], Loss: 0.8871, Constraint Loss: 1.9255
# Epoch [7570/10000], Loss: 0.8772, Constraint Loss: 1.7544
# Epoch [7580/10000], Loss: 0.8263, Constraint Loss: 1.7448
# Epoch [7590/10000], Loss: 0.8462, Constraint Loss: 1.8676
# Epoch [7600/10000], Loss: 0.8603, Constraint Loss: 1.8327
# Epoch [7610/10000], Loss: 0.9375, Constraint Loss: 1.9412
# Epoch [7620/10000], Loss: 0.8732, Constraint Loss: 1.7080
# Epoch [7630/10000], Loss: 0.8477, Constraint Loss: 1.7666
# Epoch [7640/10000], Loss: 0.8563, Constraint Loss: 2.1907
# Epoch [7650/10000], Loss: 0.8586, Constraint Loss: 1.7182
# Epoch [7660/10000], Loss: 0.8265, Constraint Loss: 1.7100
# Epoch [7670/10000], Loss: 0.9935, Constraint Loss: 3.4204
# Epoch [7680/10000], Loss: 0.8762, Constraint Loss: 3.0095
# Epoch [7690/10000], Loss: 0.8755, Constraint Loss: 2.5322
# Epoch [7700/10000], Loss: 1.3594, Constraint Loss: 13.4119
# Epoch [7710/10000], Loss: 0.8195, Constraint Loss: 3.3583
# Epoch [7720/10000], Loss: 0.7957, Constraint Loss: 2.4504
# Epoch [7730/10000], Loss: 0.8783, Constraint Loss: 4.3854
# Epoch [7740/10000], Loss: 0.8691, Constraint Loss: 2.5052
# Epoch [7750/10000], Loss: 0.8394, Constraint Loss: 2.3092
# Epoch [7760/10000], Loss: 0.7661, Constraint Loss: 1.9278
# Epoch [7770/10000], Loss: 0.7935, Constraint Loss: 1.6673
# Epoch [7780/10000], Loss: 0.7548, Constraint Loss: 1.8859
# Epoch [7790/10000], Loss: 0.7843, Constraint Loss: 1.5239
# Epoch [7800/10000], Loss: 0.8045, Constraint Loss: 2.5997
# Epoch [7810/10000], Loss: 0.8201, Constraint Loss: 1.5410
# Epoch [7820/10000], Loss: 0.8161, Constraint Loss: 4.1320
# Epoch [7830/10000], Loss: 0.8018, Constraint Loss: 2.8246
# Epoch [7840/10000], Loss: 0.8895, Constraint Loss: 3.8848
# Epoch [7850/10000], Loss: 0.9081, Constraint Loss: 2.0305
# Epoch [7860/10000], Loss: 1.0914, Constraint Loss: 3.7925
# Epoch [7870/10000], Loss: 0.8553, Constraint Loss: 2.9340
# Epoch [7880/10000], Loss: 0.9805, Constraint Loss: 5.7678
# Epoch [7890/10000], Loss: 0.7622, Constraint Loss: 2.1823
# Epoch [7900/10000], Loss: 0.8245, Constraint Loss: 2.4863
# Epoch [7910/10000], Loss: 0.8266, Constraint Loss: 3.1667
# Epoch [7920/10000], Loss: 0.8426, Constraint Loss: 2.9476
# Epoch [7930/10000], Loss: 0.8380, Constraint Loss: 3.0188
# Epoch [7940/10000], Loss: 0.8287, Constraint Loss: 2.5324
# Epoch [7950/10000], Loss: 0.8071, Constraint Loss: 2.3335
# Epoch [7960/10000], Loss: 0.7692, Constraint Loss: 2.3373
# Epoch [7970/10000], Loss: 0.8614, Constraint Loss: 2.0866
# Epoch [7980/10000], Loss: 0.8822, Constraint Loss: 4.0116
# Epoch [7990/10000], Loss: 0.7709, Constraint Loss: 2.5480
# Epoch [8000/10000], Loss: 0.8025, Constraint Loss: 2.3369
# Epoch [8010/10000], Loss: 0.7667, Constraint Loss: 1.8897
# Epoch [8020/10000], Loss: 0.7544, Constraint Loss: 1.7665
# Epoch [8030/10000], Loss: 0.7341, Constraint Loss: 1.7827
# Epoch [8040/10000], Loss: 0.9427, Constraint Loss: 2.0318
# Epoch [8050/10000], Loss: 0.8350, Constraint Loss: 4.1588
# Epoch [8060/10000], Loss: 0.8173, Constraint Loss: 3.2108
# Epoch [8070/10000], Loss: 0.8866, Constraint Loss: 3.0343
# Epoch [8080/10000], Loss: 0.9074, Constraint Loss: 5.1333
# Epoch [8090/10000], Loss: 0.7791, Constraint Loss: 2.5616
# Epoch [8100/10000], Loss: 0.9351, Constraint Loss: 5.1095
# Epoch [8110/10000], Loss: 0.8143, Constraint Loss: 2.6855
# Epoch [8120/10000], Loss: 0.8272, Constraint Loss: 2.2786
# Epoch [8130/10000], Loss: 0.7123, Constraint Loss: 2.0135
# Epoch [8140/10000], Loss: 0.7563, Constraint Loss: 2.1593
# Epoch [8150/10000], Loss: 0.6771, Constraint Loss: 1.8143
# Epoch [8160/10000], Loss: 0.7106, Constraint Loss: 1.7018
# Epoch [8170/10000], Loss: 0.7245, Constraint Loss: 1.8016
# Epoch [8180/10000], Loss: 0.7587, Constraint Loss: 1.7487
# Epoch [8190/10000], Loss: 0.7574, Constraint Loss: 1.7228
# Epoch [8200/10000], Loss: 0.7551, Constraint Loss: 1.7694
# Epoch [8210/10000], Loss: 0.8179, Constraint Loss: 1.4858
# Epoch [8220/10000], Loss: 0.8562, Constraint Loss: 1.4741
# Epoch [8230/10000], Loss: 0.7276, Constraint Loss: 1.5459
# Epoch [8240/10000], Loss: 0.7915, Constraint Loss: 2.4551
# Epoch [8250/10000], Loss: 0.7566, Constraint Loss: 1.8320
# Epoch [8260/10000], Loss: 0.7421, Constraint Loss: 1.9488
# Epoch [8270/10000], Loss: 0.7491, Constraint Loss: 1.5323
# Epoch [8280/10000], Loss: 0.7303, Constraint Loss: 1.7848
# Epoch [8290/10000], Loss: 0.7072, Constraint Loss: 1.7696
# Epoch [8300/10000], Loss: 0.7075, Constraint Loss: 1.6655
# Epoch [8310/10000], Loss: 0.7023, Constraint Loss: 1.6108
# Epoch [8320/10000], Loss: 0.7532, Constraint Loss: 1.5391
# Epoch [8330/10000], Loss: 0.7239, Constraint Loss: 1.5430
# Epoch [8340/10000], Loss: 0.6977, Constraint Loss: 1.4157
# Epoch [8350/10000], Loss: 0.7049, Constraint Loss: 1.3627
# Epoch [8360/10000], Loss: 0.8090, Constraint Loss: 1.2333
# Epoch [8370/10000], Loss: 0.9113, Constraint Loss: 1.8494
# Epoch [8380/10000], Loss: 0.7667, Constraint Loss: 1.7294
# Epoch [8390/10000], Loss: 0.7486, Constraint Loss: 1.8402
# Epoch [8400/10000], Loss: 0.7297, Constraint Loss: 1.6135
# Epoch [8410/10000], Loss: 0.7660, Constraint Loss: 1.5155
# Epoch [8420/10000], Loss: 0.6857, Constraint Loss: 1.3654
# Epoch [8430/10000], Loss: 0.7864, Constraint Loss: 1.2630
# Epoch [8440/10000], Loss: 0.7506, Constraint Loss: 5.0920
# Epoch [8450/10000], Loss: 0.7765, Constraint Loss: 3.2307
# Epoch [8460/10000], Loss: 0.8148, Constraint Loss: 2.3838
# Epoch [8470/10000], Loss: 0.8369, Constraint Loss: 2.6611
# Epoch [8480/10000], Loss: 0.6685, Constraint Loss: 1.8320
# Epoch [8490/10000], Loss: 0.6297, Constraint Loss: 1.5726
# Epoch [8500/10000], Loss: 0.6511, Constraint Loss: 1.6130
# Epoch [8510/10000], Loss: 0.7322, Constraint Loss: 1.8274
# Epoch [8520/10000], Loss: 1.0747, Constraint Loss: 2.5434
# Epoch [8530/10000], Loss: 0.7063, Constraint Loss: 1.7571
# Epoch [8540/10000], Loss: 0.7593, Constraint Loss: 2.3686
# Epoch [8550/10000], Loss: 0.6924, Constraint Loss: 1.5975
# Epoch [8560/10000], Loss: 0.7182, Constraint Loss: 1.3973
# Epoch [8570/10000], Loss: 0.6869, Constraint Loss: 1.7176
# Epoch [8580/10000], Loss: 0.7015, Constraint Loss: 1.8326
# Epoch [8590/10000], Loss: 0.7735, Constraint Loss: 1.6373
# Epoch [8600/10000], Loss: 0.7218, Constraint Loss: 1.6706
# Epoch [8610/10000], Loss: 0.6778, Constraint Loss: 1.4608
# Epoch [8620/10000], Loss: 0.7463, Constraint Loss: 1.9021
# Epoch [8630/10000], Loss: 0.6913, Constraint Loss: 2.1561
# Epoch [8640/10000], Loss: 0.9877, Constraint Loss: 4.1805
# Epoch [8650/10000], Loss: 0.7213, Constraint Loss: 3.2244
# Epoch [8660/10000], Loss: 0.6843, Constraint Loss: 1.9704
# Epoch [8670/10000], Loss: 0.7372, Constraint Loss: 1.7399
# Epoch [8680/10000], Loss: 0.7436, Constraint Loss: 1.6050
# Epoch [8690/10000], Loss: 0.8722, Constraint Loss: 1.3881
# Epoch [8700/10000], Loss: 0.7725, Constraint Loss: 1.4065
# Epoch [8710/10000], Loss: 0.7189, Constraint Loss: 1.5521
# Epoch [8720/10000], Loss: 0.7370, Constraint Loss: 1.5865
# Epoch [8730/10000], Loss: 0.7516, Constraint Loss: 1.5379
# Epoch [8740/10000], Loss: 0.7133, Constraint Loss: 1.5602
# Epoch [8750/10000], Loss: 0.7700, Constraint Loss: 1.5830
# Epoch [8760/10000], Loss: 0.6882, Constraint Loss: 1.5437
# Epoch [8770/10000], Loss: 0.6721, Constraint Loss: 1.5541
# Epoch [8780/10000], Loss: 0.6998, Constraint Loss: 1.7912
# Epoch [8790/10000], Loss: 0.7115, Constraint Loss: 1.5962
# Epoch [8800/10000], Loss: 0.7453, Constraint Loss: 1.4639
# Epoch [8810/10000], Loss: 0.8489, Constraint Loss: 4.7902
# Epoch [8820/10000], Loss: 0.8522, Constraint Loss: 4.5852
# Epoch [8830/10000], Loss: 0.7040, Constraint Loss: 1.9243
# Epoch [8840/10000], Loss: 0.7109, Constraint Loss: 1.7025
# Epoch [8850/10000], Loss: 0.7197, Constraint Loss: 1.6825
# Epoch [8860/10000], Loss: 0.7818, Constraint Loss: 2.2121
# Epoch [8870/10000], Loss: 0.7022, Constraint Loss: 2.0758
# Epoch [8880/10000], Loss: 0.7059, Constraint Loss: 1.7270
# Epoch [8890/10000], Loss: 0.7419, Constraint Loss: 1.6982
# Epoch [8900/10000], Loss: 0.6765, Constraint Loss: 1.7566
# Epoch [8910/10000], Loss: 0.7071, Constraint Loss: 1.6127
# Epoch [8920/10000], Loss: 0.6704, Constraint Loss: 1.5036
# Epoch [8930/10000], Loss: 0.6900, Constraint Loss: 1.4308
# Epoch [8940/10000], Loss: 0.6790, Constraint Loss: 1.6312
# Epoch [8950/10000], Loss: 0.6742, Constraint Loss: 1.5635
# Epoch [8960/10000], Loss: 0.6933, Constraint Loss: 1.6407
# Epoch [8970/10000], Loss: 0.7467, Constraint Loss: 1.8142
# Epoch [8980/10000], Loss: 0.6761, Constraint Loss: 1.7556
# Epoch [8990/10000], Loss: 0.6706, Constraint Loss: 1.7764
# Epoch [9000/10000], Loss: 0.6394, Constraint Loss: 1.9076
# Epoch [9010/10000], Loss: 0.7418, Constraint Loss: 3.4170
# Epoch [9020/10000], Loss: 0.6625, Constraint Loss: 1.6814
# Epoch [9030/10000], Loss: 0.6347, Constraint Loss: 1.5208
# Epoch [9040/10000], Loss: 0.7154, Constraint Loss: 1.7276
# Epoch [9050/10000], Loss: 0.6912, Constraint Loss: 1.7232
# Epoch [9060/10000], Loss: 1.4202, Constraint Loss: 8.7044
# Epoch [9070/10000], Loss: 0.6815, Constraint Loss: 2.1502
# Epoch [9080/10000], Loss: 0.7005, Constraint Loss: 2.0674
# Epoch [9090/10000], Loss: 0.6619, Constraint Loss: 2.2882
# Epoch [9100/10000], Loss: 0.6899, Constraint Loss: 1.6539
# Epoch [9110/10000], Loss: 0.6544, Constraint Loss: 1.6425
# Epoch [9120/10000], Loss: 0.6595, Constraint Loss: 1.5991
# Epoch [9130/10000], Loss: 0.6943, Constraint Loss: 1.5025
# Epoch [9140/10000], Loss: 0.6274, Constraint Loss: 1.3634
# Epoch [9150/10000], Loss: 0.9167, Constraint Loss: 1.3756
# Epoch [9160/10000], Loss: 1.5333, Constraint Loss: 2.3454
# Epoch [9170/10000], Loss: 1.2404, Constraint Loss: 1.6294
# Epoch [9180/10000], Loss: 0.9899, Constraint Loss: 1.5068
# Epoch [9190/10000], Loss: 1.9344, Constraint Loss: 1.6210
# Epoch [9200/10000], Loss: 1.3532, Constraint Loss: 1.5753
# Epoch [9210/10000], Loss: 0.8336, Constraint Loss: 1.3245
# Epoch [9220/10000], Loss: 0.8560, Constraint Loss: 1.3703
# Epoch [9230/10000], Loss: 0.9155, Constraint Loss: 1.3993
# Epoch [9240/10000], Loss: 0.9092, Constraint Loss: 1.5463
# Epoch [9250/10000], Loss: 0.8307, Constraint Loss: 1.4085
# Epoch [9260/10000], Loss: 0.8647, Constraint Loss: 2.1523
# Epoch [9270/10000], Loss: 0.8738, Constraint Loss: 1.5392
# Epoch [9280/10000], Loss: 0.9201, Constraint Loss: 1.5333
# Epoch [9290/10000], Loss: 0.9007, Constraint Loss: 1.6814
# Epoch [9300/10000], Loss: 1.0735, Constraint Loss: 1.7039
# Epoch [9310/10000], Loss: 1.0070, Constraint Loss: 1.7947
# Epoch [9320/10000], Loss: 0.9213, Constraint Loss: 1.8539
# Epoch [9330/10000], Loss: 0.8757, Constraint Loss: 1.5082
# Epoch [9340/10000], Loss: 0.8098, Constraint Loss: 1.4984
# Epoch [9350/10000], Loss: 0.8837, Constraint Loss: 1.4774
# Epoch [9360/10000], Loss: 0.8152, Constraint Loss: 1.6440
# Epoch [9370/10000], Loss: 0.9767, Constraint Loss: 1.9222
# Epoch [9380/10000], Loss: 0.7790, Constraint Loss: 1.6441
# Epoch [9390/10000], Loss: 0.7534, Constraint Loss: 1.6781
# Epoch [9400/10000], Loss: 0.7982, Constraint Loss: 1.6843
# Epoch [9410/10000], Loss: 0.8126, Constraint Loss: 1.8081
# Epoch [9420/10000], Loss: 0.8231, Constraint Loss: 1.9979
# Epoch [9430/10000], Loss: 0.7527, Constraint Loss: 1.7676
# Epoch [9440/10000], Loss: 0.7502, Constraint Loss: 1.8523
# Epoch [9450/10000], Loss: 0.7769, Constraint Loss: 1.9061
# Epoch [9460/10000], Loss: 0.8613, Constraint Loss: 1.9108
# Epoch [9470/10000], Loss: 0.8162, Constraint Loss: 1.9794
# Epoch [9480/10000], Loss: 0.8353, Constraint Loss: 1.9960
# Epoch [9490/10000], Loss: 0.7932, Constraint Loss: 2.3088
# Epoch [9500/10000], Loss: 0.9039, Constraint Loss: 2.7629
# Epoch [9510/10000], Loss: 0.7342, Constraint Loss: 1.7424
# Epoch [9520/10000], Loss: 0.7935, Constraint Loss: 1.5619
# Epoch [9530/10000], Loss: 0.8349, Constraint Loss: 2.2738
# Epoch [9540/10000], Loss: 0.9300, Constraint Loss: 3.1041
# Epoch [9550/10000], Loss: 0.7526, Constraint Loss: 1.9492
# Epoch [9560/10000], Loss: 0.7930, Constraint Loss: 1.5720
# Epoch [9570/10000], Loss: 0.9292, Constraint Loss: 1.5909
# Epoch [9580/10000], Loss: 0.8303, Constraint Loss: 1.6020
# Epoch [9590/10000], Loss: 0.8581, Constraint Loss: 1.8503
# Epoch [9600/10000], Loss: 0.7440, Constraint Loss: 1.8246
# Epoch [9610/10000], Loss: 0.7713, Constraint Loss: 1.7991
# Epoch [9620/10000], Loss: 0.7469, Constraint Loss: 1.8895
# Epoch [9630/10000], Loss: 0.7287, Constraint Loss: 2.2524
# Epoch [9640/10000], Loss: 0.6923, Constraint Loss: 1.7300
# Epoch [9650/10000], Loss: 0.9537, Constraint Loss: 2.9163
# Epoch [9660/10000], Loss: 0.9446, Constraint Loss: 3.4778
# Epoch [9670/10000], Loss: 0.9224, Constraint Loss: 6.7845
# Epoch [9680/10000], Loss: 0.7412, Constraint Loss: 2.3700
# Epoch [9690/10000], Loss: 0.7355, Constraint Loss: 1.8756
# Epoch [9700/10000], Loss: 1.3645, Constraint Loss: 9.9931
# Epoch [9710/10000], Loss: 0.7109, Constraint Loss: 2.3902
# Epoch [9720/10000], Loss: 0.6976, Constraint Loss: 2.2133
# Epoch [9730/10000], Loss: 0.6954, Constraint Loss: 1.9347
# Epoch [9740/10000], Loss: 0.7573, Constraint Loss: 2.9111
# Epoch [9750/10000], Loss: 0.7352, Constraint Loss: 2.2978
# Epoch [9760/10000], Loss: 0.8488, Constraint Loss: 2.8412
# Epoch [9770/10000], Loss: 0.8236, Constraint Loss: 4.6753
# Epoch [9780/10000], Loss: 0.7388, Constraint Loss: 2.5000
# Epoch [9790/10000], Loss: 0.8484, Constraint Loss: 3.8871
# Epoch [9800/10000], Loss: 0.7716, Constraint Loss: 3.6562
# Epoch [9810/10000], Loss: 0.7181, Constraint Loss: 2.4442
# Epoch [9820/10000], Loss: 0.8076, Constraint Loss: 2.6263
# Epoch [9830/10000], Loss: 0.7017, Constraint Loss: 2.2732
# Epoch [9840/10000], Loss: 0.7069, Constraint Loss: 1.8516
# Epoch [9850/10000], Loss: 0.6814, Constraint Loss: 1.8082
# Epoch [9860/10000], Loss: 0.6583, Constraint Loss: 1.8494
# Epoch [9870/10000], Loss: 0.7998, Constraint Loss: 1.8323
# Epoch [9880/10000], Loss: 0.8628, Constraint Loss: 1.8622
# Epoch [9890/10000], Loss: 0.6532, Constraint Loss: 1.7838
# Epoch [9900/10000], Loss: 0.6527, Constraint Loss: 1.7649
# Epoch [9910/10000], Loss: 0.7723, Constraint Loss: 1.5670
# Epoch [9920/10000], Loss: 1.0847, Constraint Loss: 1.9467
# Epoch [9930/10000], Loss: 1.3049, Constraint Loss: 1.7685
# Epoch [9940/10000], Loss: 1.6018, Constraint Loss: 1.8689
# Epoch [9950/10000], Loss: 1.6536, Constraint Loss: 1.9514
# Epoch [9960/10000], Loss: 1.8727, Constraint Loss: 1.7786
# Epoch [9970/10000], Loss: 1.6557, Constraint Loss: 2.7423
# Epoch [9980/10000], Loss: 1.0259, Constraint Loss: 3.4507
# Epoch [9990/10000], Loss: 0.8549, Constraint Loss: 4.0880

# %%
# Import required libraries
import torch
import torch.nn as nn
import torch.optim as optim
import math
import matplotlib.pyplot as plt

# Set device for computation (use GPU if available)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 1. Positional Encoding to inject information about the relative positions of tokens
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.encoding = torch.zeros(max_len, d_model, device=device)
        position = torch.arange(0, max_len, dtype=torch.float, device=device).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2, device=device).float() * (-math.log(10000.0) / d_model))
        self.encoding[:, 0::2] = torch.sin(position * div_term)
        self.encoding[:, 1::2] = torch.cos(position * div_term)
        self.encoding = self.encoding.unsqueeze(0)

    def forward(self, x):
        return x + self.encoding[:, :x.size(1), :]

# 2. Transformer Model (Encoder-Decoder architecture)
class TransformerModel(nn.Module):
    def __init__(self, input_size, d_model, nhead, num_encoder_layers, num_decoder_layers, dim_feedforward, max_len, output_size):
        super(TransformerModel, self).__init__()
        self.embedding = nn.Embedding(input_size, d_model)
        self.positional_encoding = PositionalEncoding(d_model, max_len)
        self.transformer = nn.Transformer(d_model, nhead, num_encoder_layers, num_decoder_layers, dim_feedforward)
        self.fc_out = nn.Linear(d_model, output_size)
        self.d_model = d_model

    def forward(self, src, tgt):
        src = self.embedding(src) * math.sqrt(self.d_model)
        tgt = self.embedding(tgt) * math.sqrt(self.d_model)
        
        src = self.positional_encoding(src)
        tgt = self.positional_encoding(tgt)
        
        output = self.transformer(src, tgt)
        output = self.fc_out(output)
        return output

# Hyperparameters
input_size = 1000    # Vocabulary size
output_size = 1000   # Same as input_size for translation tasks
d_model = 512        # Embedding size
nhead = 8            # Number of attention heads
num_encoder_layers = 6
num_decoder_layers = 6
dim_feedforward = 2048
max_len = 100

# Initialize the Transformer model
model = TransformerModel(input_size, d_model, nhead, num_encoder_layers, num_decoder_layers, dim_feedforward, max_len, output_size).to(device)

# Sample input
src = torch.randint(0, input_size, (10, 32)).to(device)  # (sequence_length, batch_size)
tgt = torch.randint(0, input_size, (20, 32)).to(device)  # (sequence_length, batch_size)

# Forward pass
output = model(src, tgt)
print(output.shape)  # Should output the shape (sequence_length, batch_size, output_size)
class SimpleAttention(nn.Module):
    def __init__(self, d_model, nhead):
        super(SimpleAttention, self).__init__()
        self.multihead_attn = nn.MultiheadAttention(d_model, nhead)
    
    def forward(self, query, key, value):
        attn_output, attn_weights = self.multihead_attn(query, key, value)
        return attn_output, attn_weights

# Sample inputs
src = torch.rand(10, 32, d_model).to(device)  # (sequence_length, batch_size, d_model)

# Initialize the attention layer
attention = SimpleAttention(d_model, nhead).to(device)

# Pass the source tokens through the self-attention layer
attn_output, attn_weights = attention(src, src, src)

# Visualize attention weights for one token in the sequence
plt.figure(figsize=(10, 8))
plt.title("Self-Attention Weights for One Token")
plt.imshow(attn_weights[0, :, :].cpu().detach().numpy(), cmap='Blues')
plt.xlabel("Tokens in the Sequence")
plt.ylabel("Attention Heads")
plt.colorbar()
plt.show()
# Out:
# /Users/home/Work/dev/py-venv/lib/python3.12/site-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# torch.Size([20, 32, 1000])

# %%
# A small toy dataset for translation (numbers -> text)
src_vocab = {0: "zero", 1: "one", 2: "two", 3: "three", 4: "four", 5: "five"}
tgt_vocab = {0: "cero", 1: "uno", 2: "dos", 3: "tres", 4: "cuatro", 5: "cinco"}

# Create some sample data (toy example)
src_sample = torch.tensor([[0, 1, 2, 3, 4]]).to(device)  # "zero one two three four"
tgt_sample = torch.tensor([[0, 1, 2, 3, 4]]).to(device)  # "cero uno dos tres cuatro"

# Forward pass through the model
output = model(src_sample.T, tgt_sample.T)

# Convert output to text using the target vocabulary
predicted_indices = torch.argmax(output, dim=-1).cpu().numpy()

# Print the translation
predicted_sentence = [tgt_vocab[idx] for idx in predicted_indices[:, 0]]
print(f"Predicted translation: {' '.join(predicted_sentence)}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 16
#      13 predicted_indices = torch.argmax(output, dim=-1).cpu().numpy()
#      15 # Print the translation
# ---> 16 predicted_sentence = [tgt_vocab[idx] for idx in predicted_indices[:, 0]]
#      17 print(f"Predicted translation: {' '.join(predicted_sentence)}")
#
# KeyError: np.int64(124)
